# %% [markdown]
# <a href="https://colab.research.google.com/github/umabharathi699/FMML_LAB-SESSIONS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 04:38:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   113MB/s    in 0.6s
#
# 2023-05-05 04:38:27 (113 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13160  1709.03183v1  This paper studies the problem of estimating t...  stat
# 11408  1601.00062v2  We propose two practical non-convex approaches...  stat
# 24410   1311.7327v1  Unobtrusive every day health monitoring can be...    cs
# 22445  1607.02738v2  Hamiltonian Monte Carlo (HMC) exploits Hamilto...  stat
# 24811   1412.0477v3  Given unstructured videos of deformable object...    cs
# ...             ...                                                ...   ...
# 23590   0710.2231v1  Although the recognition of isolated handwritt...    cs
# 39927  1707.08718v1  Wireless video streaming has traditionally bee...    cs
# 21812   0808.0780v1  The local linear embedding algorithm (LLE) is ...  stat
# 22076   1410.3517v2  We consider the task of fitting a regression m...  stat
# 39687  1701.08107v1  Optical endomicroscopy (OEM) is an emerging te...    cs
#
#                                                    title  year  \
# 13160  Rates of Convergence of Spectral Methods for G...  2017
# 11408  Practical Algorithms for Learning Near-Isometr...  2016
# 24410  Unobtrusive Low Cost Pupil Size Measurements u...  2013
# 22445                   Magnetic Hamiltonian Monte Carlo  2016
# 24811  Recovering Spatiotemporal Correspondence betwe...  2014
# ...                                                  ...   ...
# 23590  Comparison and Combination of State-of-the-art...  2007
# 39927         Ultra-low-power Wireless Streaming Cameras  2017
# 21812  LLE with low-dimensional neighborhood represen...  2008
# 22076  Convex Modeling of Interactions with Strong He...  2014
# 39687  Deconvolution and Restoration of Optical Endom...  2017
#
#                                                 keywords
# 13160  [estimating, underlying, generating, mechanism...
# 11408  [practical, approaches, isometric, embeddings,...
# 24410  [unobtrusive, monitoring, important, populatio...
# 22445  [hamiltonian, hamiltonian, construct, efficien...
# 24811  [unstructured, deformable, automatically, spat...
# ...                                                  ...
# 23590  [recognition, handwritten, continues, communit...
# 39927  [streaming, traditionally, considered, extreme...
# 21812  [embedding, algorithm, dimension, technique, c...
# 22076  [regression, involving, interactions, potentia...
# 39687  [endomicroscopy, technology, preclinical, pulm...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13160    [estimating, underlying, generating, mechanism...
# 11408    [practical, approaches, isometric, embeddings,...
# 24410    [unobtrusive, monitoring, important, populatio...
# 22445    [hamiltonian, hamiltonian, construct, efficien...
# 24811    [unstructured, deformable, automatically, spat...
#                                ...
# 5957     [prediction, challenging, practitioners, acade...
# 14180    [evolution, strategies, demonstrated, alternat...
# 22335    [discovering, statistically, significant, data...
# 1058     [introduce, permutation, equivariant, structur...
# 28016    [weighting, contribution, considering, fundame...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8823 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="96e326ad-ffe3-41af-888f-6286a5059c73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96e326ad-ffe3-41af-888f-6286a5059c73")) {                    Plotly.newPlot(                        "96e326ad-ffe3-41af-888f-6286a5059c73",                        [{"x":["community","predicting","probability","computational","thresholding","approaching","polynomial","relatively","piecewise","recommender","stochastic","applications","connected","computationally","increases","estimation","furthermore","procedures","algorithm","mechanism","parameter","coincides","estimating","identified","approximations","multiplicative","generating","detection","independently","characterizing","eigenvalue","convergence","dimensional","efficient","realization","underlying","smoothness","symmetric","preferences","universal","processing","algorithms","factorization","converges","dimensionality","decomposition","preserves","embeddings","projection","normalized","alternating","reduction","minimization","reformulate","empirically","demonstrated","practical","formulated","difference","frobenius","approaches","distortion","multipliers","direction","minimizing","restricted","motivated","isometric","efficiency","pathological","filtering","experimental","emotional","measurements","important","information","population","unobtrusive","estimated","subsequently","monitoring","acceptance","describes","effectiveness","particular","detecting","hamiltonian","construct","mechanics","symplectic","canonical","implementation","integrator","generalization","proposals","dimensions","theoretical","establish","deformable","traditional","trajectories","outperforms","automatically","appearance","spatiotemporal","candidates","correspondences","unstructured","alignment","consistency","intervals","thousands","exploiting","challenging","deformation","instances","recovering","correspondence","conditions","foreground","consistent","discovers","prototype","compatible","classifier","demonstrate","representative","combinatorial","desirable","highlights","successful","retaining","classification","dissimilarity","interpretable","approximating","strengths","optimization","situations","introduce","euclidean","additionally","experiments","influence","exploitation","architecture","suggested","influencing","optimizing","constraints","supermodular","surrogate","objective","exploration","selection","transformations","submodular","performance","architectures","recurrent","transformed","functions","constraint","distribution","grammatical","identifies","languages","intermediary","parameters","absolutely","enumerable","according","probabilistic","generated","efficiently","inference","representation","recursively","polylogarithmic","sparsification","processors","randomness","fundamental","numerical","precision","factoring","univariate","factorizations","complexity","graphical","statistical","dependence","treatment","unobserved","exponential","healthcare","interacts","contextual","decisions","reinforcement"],"y":[87,74,183,292,11,6,65,64,14,19,121,403,84,90,48,204,166,40,850,86,127,5,70,45,34,15,88,376,56,19,7,110,167,418,4,104,19,24,42,37,261,592,33,21,59,56,20,68,44,28,21,101,69,3,85,117,130,37,49,2,406,30,12,50,63,51,60,4,148,3,71,399,13,58,342,712,46,3,66,37,40,12,88,245,303,60,3,74,5,0,15,140,0,116,31,43,168,53,14,155,27,233,173,82,14,30,20,24,39,69,17,30,86,262,16,105,21,29,123,17,99,9,16,8,161,590,34,32,30,11,69,15,487,7,31,18,26,333,40,312,33,66,633,62,20,250,28,2,57,162,1,11,178,56,176,45,7,909,123,130,24,228,96,205,10,21,97,2,262,6,2,123,165,174,162,215,354,11,4,3,10,6,88,82,73,6,7,7,236,54,151,27,33,7,46,5,6,65,53,114],"type":"bar"},{"x":["community","predicting","probability","computational","thresholding","a ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Hi</span> <span style=''>Fi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3972602739726027);'>Integration</span> <span style=''>for</span> <span style=''>Skeleton</span> <span style='background-color:rgba(0, 255, 0, 0.5765199161425576);'>Detection</span> <br/><br/><span style=''>In</span> <span style=''>natural</span> <span style=''>images</span> <span style=''>the</span> <span style=''>scales</span> <span style=''>(thickness)</span> <span style=''>of</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>skeletons</span> <span style=''>may</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dramatically</span> <span style=''>vary</span> <span style=''>among</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>object</span> <span style=''>parts</span> <span style=''>Thus</span> <span style=''>robust</span> <span style=''>skeleton</span> <span style='background-color:rgba(0, 255, 0, 0.5765199161425576);'>detection</span> <span style=''>requires</span> <span style=''>powerful</span> <span style=''>multi</span> <span style=''>scale</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3972602739726027);'>integration</span> <span style=''>ability</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.6016260162601625);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CNN)</span> <span style='background-color:rgba(0, 255, 0, 0.567398119122257);'>architecture</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3972602739726027);'>integration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mechanism</span> <span style=''>named</span> <span style=''>Hi</span> <span style=''>Fi</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>object</span> <span style=''>skeleton</span> <span style='background-color:rgba(0, 255, 0, 0.5765199161425576);'>detection</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>CNN</span> <span style=''>based</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>intrinsically</span> <span style=''>captures</span> <span style=''>high</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.8979591836734695);'>semantics</span> <span style=''>from</span> <span style=''>deeper</span> <span style=''>layers</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>low</span> <span style=''>level</span> <span style=''>details</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>shallower</span> <span style=''>layers</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchically</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695654);'>integrating</span> <span style='background-color:rgba(0, 255, 0, 0.32633420822397197);'>different</span> <span style=''>CNN</span> <span style=''>feature</span> <span style=''>levels</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.7037037037037037);'>bidirectional</span> <span style=''>guidance</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>(1)</span> <span style=''>enables ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>graphon</span> <span style=''>Theory</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <br/><br/><span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>network</span> <span style=''>data</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exchangeable</span> <span style=''>graph</span> <span style=''>models</span> <span style=''>(ExGM)</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>gained</span> <span style=''>interest</span> <span style=''>The</span> <span style=''>key</span> <span style=''>object</span> <span style=''>that</span> <span style=''>defines</span> <span style=''>an</span> <span style=''>ExGM</span> <span style=''>is</span> <span style=''>often</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>a</span> <span style=''>graphon</span> <span style=''>This</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>on</span> <span style=''>network</span> <span style=''>modeling</span> <span style=''>poses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>on</span> <span style=''>how</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>the</span> <span style=''>graphon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>observed</span> <span style=''>network</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>a</span> <span style=''>graphon</span> <span style=''>from</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>observed</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>from</span> <span style=''>it</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>(SBA)</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graphon</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>the</span> <span style=''>graphon</span> <span style=''>with</span> <span style=''>a</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Unimodal</span> <span style=''>Bandits</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Smoothness</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3762886597938146);'>stochastic</span> <span style=''>bandit</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>set</span> <span style=''>of</span> <span style=''>arms</span> <span style=''>and</span> <span style=''>where</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>and</span> <span style=''>unimodal</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>arm</span> <span style=''>No</span> <span style=''>further</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>is</span> <span style=''>made</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothness</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>function</span> <span style=''>For</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3762886597938146);'>Stochastic</span> <span style=''>Pentachotomy</span> <span style=''>(SP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>finite</span> <span style=''>time</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>its</span> <span style=''>regret</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>error</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>for</span> <span style=''>any</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>function</span> <span style=''>mu</span> <span style=''>that</span> <span style=''>behaves</span> <span style=''>as</span> <span style=''>mu(x)mu(xstar)</span> <span style=''>C|x</span> <span style=''>xstar|xi</span> <span style=''>locally</span> <span style=''>around</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>maximizer</span> <span style=''>xstar</span> <span style=''>for</span> <span style=''>some</span> <span style=''>xi</span> <span style=''>C0</span> <span style=''>the</span> <span style=''>SP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>order</span> <span style=''>optimal</span> <span style=''>Namely</span> <span style=''>its</span> <span style=''>regret</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>error</span> <span style=''>scale</span> <span style=''>as</span> <span style=''>O(sqrtTlog(T))</span> <span style=''>and</span> <span style=''>O(sqrtlog(T)T)</span> <span style='background-color:rgba(0, 255, 0, 0.32812499999999983);'>respectively</span> <span style=''>when</span> <span style=''>the</span> <span style=''>time</span> <span style=''>horizon</span> <span style=''>T</span> <span style=''>grows</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Central</span> <span style=''>Moment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrepancy</span> <span style=''>(CMD)</span> <span style=''>for</span> <span style=''>Domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Invariant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representation</span> <span style=''>Learning</span> <br/><br/><span style=''>The</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>with</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrepancy</span> <span style=''>between</span> <span style=''>domain</span> <span style=''>specific</span> <span style=''>latent</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>directly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style=''>space</span> <span style=''>Although</span> <span style=''>some</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>exist</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>the</span> <span style=''>matching</span> <span style=''>of</span> <span style=''>weighted</span> <span style=''>sums</span> <span style=''>of</span> <span style=''>moments</span> <span style=''>eg</span> <span style=''>Maximum</span> <span style=''>Mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrepancy</span> <span style=''>(MMD)</span> <span style=''>an</span> <span style=''>explicit</span> <span style=''>order</span> <span style=''>wise</span> <span style=''>matching</span> <span style=''>of</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>moments</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>before</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>match</span> <span style=''>the</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>central</span> <span style=''>moments</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>order</span> <span style=''>wise</span> <span style=''>moment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style='background-color:rgba(0, 255, 0, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1262482168330956)
# 	architecture (0.0891583452211127)
# 	evaluation (0.10449358059914408)
# 	segmentation (0.0702567760342368)
# 	information (0.25392296718972895)
# 	experimental (0.14229671897289586)
# 	different (0.2703281027104137)
# 	detection (0.1340941512125535)
# 	convolutional (0.1405135520684736)
# 	recognition (0.13730385164051356)
#
# Some Statistics words are:
# 	theoretical (0.1467935871743487)
# 	algorithm (0.3912825651302605)
# 	stochastic (0.13376753507014028)
# 	statistical (0.14579158316633267)
# 	variables (0.1407815631262525)
# 	estimation (0.17084168336673347)
# 	distribution (0.17735470941883769)
# 	inference (0.18937875751503006)
# 	dimensional (0.18086172344689377)
# 	regression (0.1818637274549098)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="765ad2c5-a4f3-4d84-9d75-d19b2724a740" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("765ad2c5-a4f3-4d84-9d75-d19b2724a740")) {                    Plotly.newPlot(                        "765ad2c5-a4f3-4d84-9d75-d19b2724a740",                        [{"x":["community","predicting","probability","computational","thresholding","approaching","polynomial","relatively","piecewise","recommender","stochastic","applications","connected","computationally","increases","estimation","furthermore","procedures","algorithm","mechanism","parameter","coincides","estimating","identified","approximations","multiplicative","generating","detection","independently","characterizing","eigenvalue","convergence","dimensional","efficient","realization","underlying","smoothness","symmetric","preferences","universal","processing","algorithms","factorization","converges","dimensionality","decomposition","preserves","embeddings","projection","normalized","alternating","reduction","minimization","reformulate","empirically","demonstrated","practical","formulated","difference","frobenius","approaches","distortion","multipliers","direction","minimizing","restricted","motivated","isometric","efficiency","pathological","filtering","experimental","emotional","measurements","important","information","population","unobtrusive","estimated","subsequently","monitoring","acceptance","describes","effectiveness","particular","detecting","hamiltonian","construct","mechanics","symplectic","canonical","implementation","integrator","generalization","proposals","dimensions","theoretical","establish","deformable","traditional","trajectories","outperforms","automatically","appearance","spatiotemporal","candidates","correspondences","unstructured","alignment","consistency","intervals","thousands","exploiting","challenging","deformation","instances","recovering","correspondence","conditions","foreground","consistent","discovers","prototype","compatible","classifier","demonstrate","representative","combinatorial","desirable","highlights","successful","retaining","classification","dissimilarity","interpretable","approximating","strengths","optimization","situations","introduce","euclidean","additionally","experiments","influence","exploitation","architecture","suggested","influencing","optimizing","constraints","supermodular","surrogate","objective","exploration","selection","transformations","submodular","performance","architectures","recurrent","transformed","functions","constraint","distribution","grammatical","identifies","languages","intermediary","parameters","absolutely","enumerable","according","probabilistic","generated","efficiently","inference","representation","recursively","polylogarithmic","sparsification","processors","randomness","fundamental","numerical","precision","factoring","univariate","factorizations","complexity","graphical","statistical","dependence","treatment","unobserved","exponential","healthcare","interacts","contextual","decisions","reinforcement","techniques","determines","assumption","combinations","dimension","processes","tractable","continuous","characterized","literature","introduced","structured","taxonomies","presented","hierarchical","contribution","discussed","simulations","application","achieving","coordinates","illustrated","evaluations","approximation","perturbation","estimator","compressive","sensitive","simultaneous","dependent","cognitive","distributions","observable","uncertainties","stochastically","environments","dependencies","communication","destination","aggregated","maintaining","logarithmic","individual","formulate","framework","connecting","assigning","constrained","particularly","introduces","arbitrary","typically","supervised","intuiti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	symplectic
# 	integrator
# 	procrustes
# 	chebyshev
# 	compresses
# 	penalization
# 	whitening
# 	changepoints
# 	exacerbated
# 	activating
# 	diagnosed
# 	ulcerative
# 	colorectal
# 	approachability
# 	projectorg
# 	forecaster
# 	undetermined
# 	reconcile
# 	subgroups
# 	forthcoming
# Some words which never appear in Statistics papers:
# 	unobtrusive
# 	deformable
# 	deformation
# 	grammatical
# 	intermediary
# 	enumerable
# 	processors
# 	taxonomies
# 	unsatisfiable
# 	undertake
# 	reviewers
# 	femtocell
# 	femtocells
# 	connectives
# 	certainty
# 	proposition
# 	propositions
# 	container
# 	containers
# 	vibration

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067955207853966e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
